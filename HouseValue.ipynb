# %% [markdown]
# <a href="https://colab.research.google.com/github/GuiOSousa/HouseValueRegression/blob/RandomForestRegressor/HouseValue.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Preparando o Ambiente

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Tratando os Dados

# %% [markdown]
# ##Acessando a base de dados

# %%
import pandas as pd

dataset = pd.read_csv('/content/drive/MyDrive/Datasets/HouseRentData/house_prices.csv')

dataset
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
#        population  households  median_income ocean_proximity  \
# 0             322         126         8.3252        NEAR BAY
# 1            2401        1138         8.3014        NEAR BAY
# 2             496         177         7.2574        NEAR BAY
# 3             558         219         5.6431        NEAR BAY
# 4             565         259         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635         845         330         1.5603          INLAND
# 20636         356         114         2.5568          INLAND
# 20637        1007         433         1.7000          INLAND
# 20638         741         349         1.8672          INLAND
# 20639        1387         530         2.3886          INLAND
#
#        median_house_value
# 0                  452600
# 1                  358500
# 2                  352100
# 3                  341300
# 4                  342200
# ...                   ...
# 20635               78100
# 20636               77100
# 20637               92300
# 20638               84700
# 20639               89400
#
# [20640 rows x 10 columns]

# %% [markdown]
# ##Tratando valores NaN e nulos

# %%
print(dataset.isna().sum())
print(dataset.isnull().sum())
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# ocean_proximity         0
# median_house_value      0
# dtype: int64
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# ocean_proximity         0
# median_house_value      0
# dtype: int64

# %% [markdown]
# Como nossos valores NaN/nulos representam uma parcela mínima da nossa base de dados, podemos optar por simplesmente excuí-los, sem que haja impactos significantes no treinamento do modelo

# %%
dataset = dataset.dropna()
dataset = dataset.reset_index(drop=True)

# %% [markdown]
# ##Decodificando valores de texto em valores numéricos
#
# Modelos de linguagem geralmente requerem uma decodificação quando trabalhamos com Strings.

# %% [markdown]
# No bloco abaixo, substituimos a "distância do mar", atributo descrito em texto, por valores inteiros.

# %%
datasetEncoded = dataset[:]

datasetEncoded = datasetEncoded.replace("ISLAND", 0)
datasetEncoded = datasetEncoded.replace("NEAR BAY", 1)
datasetEncoded = datasetEncoded.replace("NEAR OCEAN", 2)
datasetEncoded = datasetEncoded.replace("<1H OCEAN", 3)
datasetEncoded = datasetEncoded.replace("INLAND", 4)

datasetEncoded
# Out:
# <ipython-input-16-edbe6781ec6d>:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   datasetEncoded = datasetEncoded.replace("INLAND", 4)
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20428    -121.09     39.48                  25         1665           374.0
# 20429    -121.21     39.49                  18          697           150.0
# 20430    -121.22     39.43                  17         2254           485.0
# 20431    -121.32     39.43                  18         1860           409.0
# 20432    -121.24     39.37                  16         2785           616.0
#
#        population  households  median_income  ocean_proximity  \
# 0             322         126         8.3252                1
# 1            2401        1138         8.3014                1
# 2             496         177         7.2574                1
# 3             558         219         5.6431                1
# 4             565         259         3.8462                1
# ...           ...         ...            ...              ...
# 20428         845         330         1.5603                4
# 20429         356         114         2.5568                4
# 20430        1007         433         1.7000                4
# 20431         741         349         1.8672                4
# 20432        1387         530         2.3886                4
#
#        median_house_value
# 0                  452600
# 1                  358500
# 2                  352100
# 3                  341300
# 4                  342200
# ...                   ...
# 20428               78100
# 20429               77100
# 20430               92300
# 20431               84700
# 20432               89400
#
# [20433 rows x 10 columns]

# %% [markdown]
# ##Atributos de posição
#
# Embora Latitude e Longitude não sejam os melhores atributos para se analisar quando fatores socioeconômicos são mais importantes que a posição física do objeto em questão, materemos ambas pois não possuímos, na base de dados, outros dados referentes a localização.
#
# No contexto dado, informações como estado, cidade/distrito, bairros, etc. trariam análises mais relevantes, portanto seria mais prudente remover as colunas de Latitude e Longitude.*texto em itálico*

# %% [markdown]
# #Separando Teste e Treinamento

# %%
trainingDataset = datasetEncoded.sample(frac=0.9)

trainingDataset
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11479    -118.07     33.80                  34         3486           507.0
# 10555    -117.81     33.66                  20         2851           490.0
# 20326    -121.67     38.54                  13         6141          1019.0
# 5510     -118.28     33.88                  19         2758           675.0
# 9636     -121.72     36.81                  18         1984           379.0
# ...          ...       ...                 ...          ...             ...
# 5708     -118.27     34.16                  47         1453           356.0
# 17012    -122.47     37.50                  25          950           259.0
# 10286    -117.65     33.58                   2         2411           354.0
# 10471    -117.69     33.64                  18         3783           654.0
# 16999    -122.21     37.37                  34         1476           217.0
#
#        population  households  median_income  ocean_proximity  \
# 11479        1311         503         7.1221                3
# 10555        1192         463         5.8752                3
# 20326        2553         967         4.2432                4
# 5510         2047         591         2.6618                3
# 9636         1078         359         3.2969                3
# ...           ...         ...            ...              ...
# 5708          787         345         3.0114                3
# 17012         404         195         3.1937                2
# 10286         703         217         7.8061                3
# 10471        1843         623         5.7559                3
# 16999         613         223         8.2883                2
#
#        median_house_value
# 11479              384500
# 10555              274200
# 20326              326500
# 5510               179700
# 9636               229900
# ...                   ...
# 5708               255500
# 17012              319200
# 10286              331400
# 10471              215800
# 16999              500001
#
# [18390 rows x 10 columns]

# %%
X_trainingDataset = trainingDataset.drop("median_house_value", axis=1)
Y_trainingDataset = trainingDataset.drop(X_trainingDataset, axis=1)

# %%
testDataset = datasetEncoded.drop(trainingDataset.index)

testDataset
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 6        -122.25     37.84                  52         2535           489.0
# 14       -122.26     37.85                  52         2643           626.0
# 20       -122.27     37.85                  40          751           184.0
# 24       -122.27     37.84                  52         2224           437.0
# 51       -122.27     37.82                  43         1868           456.0
# ...          ...       ...                 ...          ...             ...
# 20362    -121.76     38.66                  17         5320           984.0
# 20378    -122.04     38.68                  26         1113           222.0
# 20407    -121.54     39.08                  26         2276           460.0
# 20416    -121.37     39.03                  32         1158           244.0
# 20432    -121.24     39.37                  16         2785           616.0
#
#        population  households  median_income  ocean_proximity  \
# 6            1094         514         3.6591                1
# 14           1212         620         1.9167                1
# 20            409         166         1.3578                1
# 24           1006         422         2.6000                1
# 51           1061         407         1.5045                1
# ...           ...         ...            ...              ...
# 20362        2866         928         4.1997                4
# 20378         689         234         3.0486                4
# 20407        1455         474         2.4695                4
# 20416         598         227         2.8235                4
# 20432        1387         530         2.3886                4
#
#        median_house_value
# 6                  299200
# 14                 159200
# 20                 147500
# 24                 132600
# 51                  93800
# ...                   ...
# 20362              133400
# 20378               83600
# 20407               58000
# 20416               65500
# 20432               89400
#
# [2043 rows x 10 columns]

# %%
X_testDataset = testDataset.drop("median_house_value", axis=1)
Y_testDataset = testDataset.drop(X_testDataset, axis=1)

# %% [markdown]
# #Gradient Boosting Regressor
# Utilizamos um Gradient Boosting Regressor genérico (sem alteração nos hiperparâmetros) para a tarefa de regressão.
#
# O Gradient Boosting Regressor é um modelo de ensemble (combina modelos mais fracos em modelos mais fortes durante o treinamento) de Árvores de Decisão de forma sequencial.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error

model = GradientBoostingRegressor()

model.fit(X_trainingDataset, Y_trainingDataset)

prediction = model.predict(X_testDataset)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_gb.py:672: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)  # TODO: Is this still required?

# %%
predictionDataFrame = pd.DataFrame(prediction)

predictionDataFrame
# Out:
#                   0
# 0     249111.475983
# 1     170946.589862
# 2     146673.029602
# 3     195755.873409
# 4     154637.756625
# ...             ...
# 2038  153596.898285
# 2039  103539.901569
# 2040   86451.115116
# 2041  101851.737801
# 2042   89120.580787
#
# [2043 rows x 1 columns]

# %% [markdown]
# ##Avaliando as predições
#
# Métricas comuns como MAE e MSE são difíceis de interpretar pois nossos valores não estão normalizados, então MAPE, RSMLE e R² foram escolhidas.
#
# Como nossos resultados são predições de preços de propriedades, que apresentam valores na casa das centenas de milhar, MAE e MSE apresentariam valores extremamente altos independente da qualidade do modelo, portanto, pouco confiáveis para dizer a qualidade das previsões.

# %%
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_log_error, r2_score
import numpy as np


mape = mean_absolute_percentage_error(Y_testDataset, predictionDataFrame)
msle = mean_squared_log_error(Y_testDataset, predictionDataFrame)
r2 = r2_score(Y_testDataset, predictionDataFrame)
rmsle = np.sqrt(msle)

print(f"MAPE: {mape:.2f}")
print(f"RMSLE: {rmsle:.2f}")
print(f"R2: {r2:.2f}")
# Out:
# MAPE: 0.21
# RMSLE: 0.27
# R2: 0.77

# %% [markdown]
# Analisando os valores de MAPE, RSMLE e R², podemos concluir que os resultados foram aceitáveis para um modelo genérico, considerando também que váriaveis de localização melhores levariam a predições mais precisas.
#
# A pouca diferença entre MAPE (Mean Absolute Percentage Error) e RMSLE (Root Mean Squared Logarithmic Error) indica que não houve uma grande quantidade de erros críticos, em que os valores da predição e da verdade são completamente destoantes.

# %% [markdown]
# ##Plotagem do Mapa

# %%
import folium
from folium.plugins import *
from google.colab import output

map = folium.Map(tiles='openstreetmap',location=[36.69245689448622, -119.7175285756223],zoom_start=7,zoom_control=True)

# %%
import math

housesLayer = folium.FeatureGroup(name="Houses", show=True)

for i in range(len(testDataset)-1):
  house = testDataset.iloc[i]
  coordinates = [house['latitude'], house['longitude']]
  truePrice = Y_testDataset.iloc[i, 0]
  predictedPrice = int(predictionDataFrame.iloc[i,0])

  error = math.fabs((predictedPrice - truePrice)/truePrice)
  if error <= 0.05:
    color = 'blue'
  elif error <= 0.1:
    color = 'green'
  elif error <= 0.2:
    color = 'yellow'
  elif error <= 0.5:
    color = 'orange'
  else:
     color = 'red'



  housePopup = folium.Popup(f"Predicted Price: {predictedPrice}<br>Real Price: {int(truePrice)}", max_width=500)
  houseMarker = folium.CircleMarker(location=coordinates,
                                    popup= housePopup,
                                    fill_color = color,
                                    fill_opacity = 0.6,
                                    stroke = False,
                                     ).add_to(map)

housesLayer.add_to(map)

# %%
map.save('map.html')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_31a5206937c9e4a0bc43dec1f2de7b87 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_31a5206937c9e4a0bc43dec1f2de7b87&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_31a5206937c9e4a0bc43dec1f2de7b87 = L.map(
#                 &quot;map_31a5206937c9e4a0bc43dec1f2de7b87&quot;,
#                 {
#                     center: [36.69245689448622, -119.7175285756223],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_650aead47d2387c983ecdb0c0c5d3a8d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_650aead47d2387c983ecdb0c0c5d3a8d.addTo(map_31a5206937c9e4a0bc43dec1f2de7b87);
#
#
#             var circle_marker_32c043b6300a54bf45176691bf4275de = L.circleMarker(
#                 [37.84, -122.25],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: false, &quot;weight&quot;: 3}
#             ).addTo(map_31a5206937c9e4a0bc43dec1f2de7b87);
#
#
#         var popup_8fd4c30c796fef2cd83bfae6352dd1e4 = L.popup({
#   &quot;maxWidth&quot;: 500,
# });
#
#
#
#                 var html_1890d8508243b0c9c473ae99b7630d52 = $(`&lt;div id=&quot;html_1890d8508243b0c9c473ae99b7630d52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Predicted Price: 249111&lt;br&gt;Real Price: 299200&lt;/div&gt;`)[0];
#                 popup_8fd4c30c796fef2cd83bfae6352dd1e4.setContent(html_1890d8508243b0c9c473ae99b7630d52);
#
#
#
#         circle_marker_32c043b6300a54bf45176691bf4275de.bindPopup(popup_8fd4c30c796fef2cd83bfae6352dd1e4)
#         ;
#
#
#
#
#             var circle_marker_7efe203b38a78fbb2b586329e73fa9a4 = L.circleMarker(
#                 [37.85, -122.26],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: false, &quot;weight&quot;: 3}
#             ).addTo(map_31a5206937c9e4a0bc43dec1f2de7b87);
#
#
#         var popup_c69dcf1e5fee1d8f500ad1d39e0671a9 = L.popup({
#   &quot;maxWidth&quot;: 500,
# });
#
#
#
#                 var html_65b07fea79e4456c6dbe2b6ecbb73b54 = $(`&lt;div id=&quot;html_65b07fea79e4456c6dbe2b6ecbb73b54&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Predicted Price: 170946&lt;br&gt;Real Price: 159200&lt;/div&gt;`)[0];
#                 popup_c69dcf1e5fee1d8f500ad1d39e0671a9.setContent(html_65b07fea79e4456c6dbe2b6ecbb73b54);
#
#
#
#         circle_marker_7efe203b38a78fbb2b586329e73fa9a4.bindPopup(popup_c69dcf1e5fee1d8f500ad1d39e0671a9)
#         ;
#
#
#
#
#             var circle_marker_ea6743f7641e86da383eee8ef4321088 = L.circleMarker(
#                 [37.85, -122.27],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: false, &quot;weight&quot;: 3}
#             ).addTo(map_31a5206937c9e4a0bc43dec1f2de7b87);
#
#
#         var popup_dbf8c3239cf99776cdb50879fe900914 = L.popup({
#   &quot;maxWidth&quot;: 500,
# });
#
#
#
#                 var html_20426201592fc69b4deb7265dba9cc64 = $(`&lt;div id=&quot;html_20426201592fc69b4deb7265dba9cc64&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Predicted Price: 146673&lt;br&gt;Real Price: 147500&lt;/div&gt;`)[0];
#                 popup_dbf8c3239cf99776cdb50879fe900914.setContent(html_20426201592fc69b4deb7265dba9cc64);
#
#
#
#         circle_marker_ea6743f7641e86da383eee8ef4321088.bindPopup(popup_dbf8c3239cf99776cdb50879fe900914)
#         ;
#
#
#
#
#             var circle_marker_d513ab1d50bd8e4b98ec5aada537ecca = L.circleMarker(
#                 [37.84, -122.27],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dash

# %% [markdown]
# #Random Forest Regressor
#
# O Random Forest Regressor é um modelo de ensemble que combina os resultados de Decision Trees. Diferente do GBR, este modelo cria as DTs de forma paralela, combinando apenas os resultados.

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score


model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_trainingDataset, Y_trainingDataset)


y_pred = model.predict(X_testDataset)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %% [markdown]
# ##Avaliando as Predições

# %% [markdown]
# Foram usadas as mesmas métricas do modelo anterior

# %%
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_log_error, r2_score
import numpy as np


mape = mean_absolute_percentage_error(Y_testDataset, y_pred)
msle = mean_squared_log_error(Y_testDataset, y_pred)
r2 = r2_score(Y_testDataset, y_pred)
rmsle = np.sqrt(msle)

print(f"MAPE: {mape:.2f}")
print(f"RMSLE: {rmsle:.2f}")
print(f"R2: {r2:.2f}")
# Out:
# MAPE: 0.17
# RMSLE: 0.23
# R2: 0.82

# %% [markdown]
# O RFR, quando comparado com o modelo GBR testado anteriormente, apresentou mlehora em todas as métricas comparadas.
# Valores menores no MAPE indicam menores erros percentuais, no RSLE indicam erros menores na média e valores maiores no R2 indicam que o modelo explica melhor a variabilidade dos preços.

# %%
predictionRandomForestRegressor = pd.DataFrame(y_pred)

predictionRandomForestRegressor
# Out:
#               0
# 0     255565.00
# 1     186952.00
# 2     140599.01
# 3     164266.00
# 4     125012.00
# ...         ...
# 2038  159242.00
# 2039  112207.00
# 2040   91685.00
# 2041  107988.00
# 2042   86787.00
#
# [2043 rows x 1 columns]

# %% [markdown]
# ##Plotagem do Mapa

# %%
import folium
from folium.plugins import *
from google.colab import output

map = folium.Map(tiles='openstreetmap',location=[36.69245689448622, -119.7175285756223],zoom_start=7,zoom_control=True)

# %%
import math

housesLayer = folium.FeatureGroup(name="Houses", show=True)

for i in range(len(testDataset)-1):
  house = testDataset.iloc[i]
  coordinates = [house['latitude'], house['longitude']]
  truePrice = Y_testDataset.iloc[i, 0]
  predictedPrice = int(predictionRandomForestRegressor.iloc[i,0])

  error = math.fabs((predictedPrice - truePrice)/truePrice)
  if error <= 0.05:
    color = 'blue'
  elif error <= 0.1:
    color = 'green'
  elif error <= 0.2:
    color = 'yellow'
  elif error <= 0.5:
    color = 'orange'
  else:
     color = 'red'



  housePopup = folium.Popup(f"Predicted Price: {predictedPrice}<br>Real Price: {int(truePrice)}", max_width=500)
  houseMarker = folium.CircleMarker(location=coordinates,
                                    popup= housePopup,
                                    fill_color = color,
                                    fill_opacity = 0.6,
                                    stroke = False,
                                     ).add_to(map)

housesLayer.add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_025604dbc844001a0ca98b39eb34912e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_025604dbc844001a0ca98b39eb34912e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_025604dbc844001a0ca98b39eb34912e = L.map(
#                 &quot;map_025604dbc844001a0ca98b39eb34912e&quot;,
#                 {
#                     center: [36.69245689448622, -119.7175285756223],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_acabd1c452dcc1c559a9d0b3249f8e5d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_acabd1c452dcc1c559a9d0b3249f8e5d.addTo(map_025604dbc844001a0ca98b39eb34912e);
#
#
#             var circle_marker_30c363f62f43b964353a09f2c0bdf822 = L.circleMarker(
#                 [37.84, -122.25],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: false, &quot;weight&quot;: 3}
#             ).addTo(map_025604dbc844001a0ca98b39eb34912e);
#
#
#         var popup_916c18766115f57d20c4781a84a656d0 = L.popup({
#   &quot;maxWidth&quot;: 500,
# });
#
#
#
#                 var html_fbeb49132e413cc620c3da34b40fbae6 = $(`&lt;div id=&quot;html_fbeb49132e413cc620c3da34b40fbae6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Predicted Price: 255565&lt;br&gt;Real Price: 299200&lt;/div&gt;`)[0];
#                 popup_916c18766115f57d20c4781a84a656d0.setContent(html_fbeb49132e413cc620c3da34b40fbae6);
#
#
#
#         circle_marker_30c363f62f43b964353a09f2c0bdf822.bindPopup(popup_916c18766115f57d20c4781a84a656d0)
#         ;
#
#
#
#
#             var circle_marker_c27412214c0da00d45be3f82cd7ecdb0 = L.circleMarker(
#                 [37.85, -122.26],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: false, &quot;weight&quot;: 3}
#             ).addTo(map_025604dbc844001a0ca98b39eb34912e);
#
#
#         var popup_e8e8d02e278d66703171c6aa0871c47c = L.popup({
#   &quot;maxWidth&quot;: 500,
# });
#
#
#
#                 var html_5406d9efcade07976e0ed554c38b8bc1 = $(`&lt;div id=&quot;html_5406d9efcade07976e0ed554c38b8bc1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Predicted Price: 186952&lt;br&gt;Real Price: 159200&lt;/div&gt;`)[0];
#                 popup_e8e8d02e278d66703171c6aa0871c47c.setContent(html_5406d9efcade07976e0ed554c38b8bc1);
#
#
#
#         circle_marker_c27412214c0da00d45be3f82cd7ecdb0.bindPopup(popup_e8e8d02e278d66703171c6aa0871c47c)
#         ;
#
#
#
#
#             var circle_marker_f112c52ee713574964f423d464d07b73 = L.circleMarker(
#                 [37.85, -122.27],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: false, &quot;weight&quot;: 3}
#             ).addTo(map_025604dbc844001a0ca98b39eb34912e);
#
#
#         var popup_5b5a62570edbcfcd39fd7ff7107b167d = L.popup({
#   &quot;maxWidth&quot;: 500,
# });
#
#
#
#                 var html_b0c277f8d5163a20591aaf35968f1cb1 = $(`&lt;div id=&quot;html_b0c277f8d5163a20591aaf35968f1cb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Predicted Price: 140599&lt;br&gt;Real Price: 147500&lt;/div&gt;`)[0];
#                 popup_5b5a62570edbcfcd39fd7ff7107b167d.setContent(html_b0c277f8d5163a20591aaf35968f1cb1);
#
#
#
#         circle_marker_f112c52ee713574964f423d464d07b73.bindPopup(popup_5b5a62570edbcfcd39fd7ff7107b167d)
#         ;
#
#
#
#
#             var circle_marker_4f69706489246537fae641f3d2ac0a17 = L.circleMarker(
#                 [37.84, -122.27],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;das
